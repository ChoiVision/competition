# %%
import h5py
import random
import pandas as pd
import numpy as np
import os
import glob
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

# %%
all_df = pd.read_csv('./data/train.csv')
all_points = h5py.File('./data/train.h5', 'r')

# %%
all_points = h5py.File('./data/test.h5', 'r')
all_points['89999']
# Out:
# <HDF5 dataset "89999": shape (21800, 3), type "<f8">

# %%
display(all_df)
# Out:
#           ID  label
# 0          0      5
# 1          1      0
# 2          2      4
# 3          3      1
# 4          4      9
# ...      ...    ...
# 49995  49995      5
# 49996  49996      0
# 49997  49997      8
# 49998  49998      4
# 49999  49999      8
#
# [50000 rows x 2 columns]

# %% [markdown]
# - training set은 총 5만개 임

# %%
label_cnt = dict(all_df['label'].value_counts().sort_index())
f, axs = plt.subplots(1,1, figsize=(15, 5))

axs.bar(label_cnt.keys(), label_cnt.values(), color=['#e6e6fa' if a%2==0 else '#50bcdf' for a in range(len(label_cnt))])
for k, v in label_cnt.items() :
    axs.annotate('%d'%(v), xy=(k, v), textcoords='data', ha='center',fontsize=15)

axs.set_xticks([i for i in range(0, 10)])
axs.set_xticklabels(label_cnt.keys(), fontsize=15)

plt.show()

# %% [markdown]
# # point cloud

# %%
from copy import deepcopy
new_df = deepcopy(all_df)

# %%
new_df['shape'] = [all_points[str(i)][:].shape for i in range(len(all_df))]

# %%
new_df[new_df['label'] == 5]['shape']
# Out:
# 0        (25700, 3)
# 11       (16850, 3)
# 35       (19600, 3)
# 47       (19950, 3)
# 65       (17450, 3)
#             ...
# 49950    (25400, 3)
# 49957    (28100, 3)
# 49991    (28250, 3)
# 49992    (25900, 3)
# 49995    (26100, 3)
# Name: shape, Length: 4506, dtype: object

# %% [markdown]
# - 같은 라벨이라도 shape이 다름
# - point 개수가 다르니 글씨의 크기 혹은 point의 밀도가 다를 거라 예상

# %%
display(all_points["5"][:])
display(all_points["5"][:].shape)
# Out:
# array([[ 0.15      ,  0.02248134,  0.48498134],
#        [ 0.15      ,  0.03498134,  0.48498134],
#        [ 0.15      ,  0.04748134,  0.48498134],
#        ...,
#        [ 0.15      , -0.17751866, -0.39001866],
#        [ 0.15      , -0.17751866, -0.40251866],
#        [ 0.15      , -0.17751866, -0.41501866]])
# (26800, 3)

# %% [markdown]
# - x, y, z 값으로 이루어져 있는 Numpy 배열
# - normalization 된 좌표값을 가짐

# %%
f, axs = plt.subplots(3,4, figsize=(15, 15), subplot_kw={"projection":'3d'})
axs = axs.flatten()
rand_pick = np.random.randint(0,50000,size=12)

for i, pick in enumerate(rand_pick) :
    x = all_points[str(pick)][:,0]
    y = all_points[str(pick)][:,1]
    z = all_points[str(pick)][:,2]

    axs[i].scatter(x,y,z, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
    axs[i].set_title(str(all_points[str(pick)][:].shape))
    axs[i].view_init(elev=30.)

# %% [markdown]
# - 손 글씨 형태의 숫자 모양을 하고 있음
# - 정면을 바라보고 있음
# - 좌표가 듬성듬성 찍혀 있는 데이터도 있음
# - 완벽하게 숫자만 써져있는게 아니라 점?? 같은 것도 찍혀있음

# %% [markdown]
# ### 회전된 데이터

# %%
def trans_axis_range(point, axis=[0]) :
    point = np.array(point)
    train_range = np.array([(-0.1579, 0.1579), (-0.7023, 0.6843), (-0.6795, 0.6597)])
    test_range = np.array([(-0.7839, 0.7732), (-0.7591, 0.7707), (-0.7849, 0.7697)])
    # Transform train point range to test point range
    point[:, axis] = point[:, axis] / (np.max(np.abs(train_range[axis])) + 0.1) * (np.min(np.abs(test_range[axis])) - 0.1)

    return point
    
def rand_degree(*rotation_range) :
    assert len([rotation_range]) != 2, 'expected 2 parameters, but given more or less'
    return np.random.uniform(*rotation_range)

def rotate(a, b, c, dots):
    mx = np.array([[1, 0, 0], [0, np.cos(a), -np.sin(a)], [0, np.sin(a), np.cos(a)]])
    my = np.array([[np.cos(b), 0, np.sin(b)], [0, 1, 0], [-np.sin(b), 0, np.cos(b)]])
    mz = np.array([[np.cos(c), -np.sin(c), 0], [np.sin(c), np.cos(c), 0], [0, 0, 1]])
    m = np.dot(np.dot(mx,my),mz)
    dots = np.dot(dots, m.T)
    return dots

all_points = h5py.File('./data/train.h5', 'r')
f, axs = plt.subplots(3,4, figsize=(15, 15), subplot_kw={"projection":'3d'})
axs = axs.flatten()
rand_pick = np.random.randint(0,50000,size=12)

for i, pick in enumerate(rand_pick) :
    
    points= trans_axis_range(all_points[str(pick)], axis=[0,1,2])
    
    x_degree = rand_degree(-np.pi/6, -np.pi/4) #np.random.choice([-np.pi/5, 0, np.pi/5])
    y_degree = rand_degree(-np.pi/2.5, -np.pi/2)
    z_degree = np.random.choice([np.pi/5, -np.pi/5]) #rand_degree(-np.pi/4, np.pi/4)

    points = rotate(x_degree, y_degree, z_degree, points)
            
    x = points[:,0]
    y = points[:,1]
    z = points[:,2]

    axs[i].scatter(x,y,z, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
    axs[i].set_title(str(all_points[str(pick)][:].shape))
    axs[i].view_init(elev=30.)#90. ,azim=-5)

# %% [markdown]
# # PCA - train

# %%
def jittering(point, scale_range) :
    point += np.random.uniform(*scale_range, size=point.shape) 
    return point

def scaling(point, scale_range) :
    point *= np.random.uniform(*scale_range)
    return point

def rand_sampling(point) :
    point_num = point.shape[0]

#     if point_num >= 20000 :
#         sampling_rate=0.6
#     else :
#         sampling_rate=0.8
    sampling_rate=0.5
    sampling_idx = np.sort(np.random.choice(point_num, int(point_num * sampling_rate) , replace=False))
    point = point[sampling_idx, :]
    return point

# %%
f, axs = plt.subplots(3,4, figsize=(15, 15))
axs = axs.flatten()
np.random.seed(2455)
rand_pick = np.random.randint(0,50000,size=12)

for i, pick in enumerate(rand_pick) :
    point = np.array(all_points[str(pick)])
#     point = rand_sampling(point)
#     point = jittering(point, [-0.01, 0.01])
#     point = scaling(point, [1.5, 1.8])
    
    pca = PCA(n_components=2)
    pt_pca = pca.fit_transform(point)
    pt_pca = rand_sampling(pt_pca)
    
    x = pt_pca[:,0]
    y = pt_pca[:,1]

    axs[i].scatter(x,y, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
    axs[i].set_title(str(all_df['label'][pick]))
#     axs[i].view_init(elev=30.)

# %% [markdown]
# # PCA - test

# %%
test_points = h5py.File('./data/test.h5', 'r')

# %%
f, axs = plt.subplots(3,4, figsize=(15, 15))
axs = axs.flatten()
np.random.seed(2455)
rand_pick = np.random.randint(50000, 90000,size=12)

for i, pick in enumerate(rand_pick) :
    point = np.array(test_points[str(pick)])
    point = rand_sampling(point)
    point = jittering(point, [-0.01, 0.01])
    point = scaling(point, [1.5, 1.8])
    pca = PCA(n_components=2)
    pt_pca = pca.fit_transform(point)
    
    
    x = pt_pca[:,0]
    y = pt_pca[:,1]

    axs[i].scatter(x,y, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
#     axs[i].set_title(str(all_df['label'][pick]))
#     axs[i].view_init(elev=30.)

# %% [markdown]
# # Point 분포

# %%
total_size = []
for i in tqdm(range(0, 50000)) :
    total_size.append(all_points[str(i)].shape[0])

total_size = np.array(total_size)
smallest_idx = np.argmin(total_size)
biggest_idx = np.argmax(total_size)

print("가장 많은 point : ",all_points[str(biggest_idx)].shape)
print("가장 적은 point : ",all_points[str(smallest_idx)].shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 50000/50000 [00:03<00:00, 14745.52it/s]
# 가장 많은 point :  (38200, 3)
# 가장 적은 point :  (8600, 3)

# %%
section_list = {k : [] for k in range(8000,39000, 2000)}
_section_num = {str(k) : 0 for k in range(8000,39000, 2000)}

for i, shape in enumerate(total_size) :
    for k in section_list.keys() :
        if k < shape and shape <= k + 2000 :
            section_list[k].append((shape, str(i))) 
            _section_num[str(k)] += 1
            
f, axs = plt.subplots(1,1, figsize=(15, 7))

axs.bar(_section_num.keys(), _section_num.values(), color=['#e6e6fa' if a%2==0 else '#50bcdf' for a in range(len(_section_num))])
for k, v in _section_num.items() :
    axs.annotate('%d'%(v), xy=(k, v), ha='center',fontsize=15)

axs.set_xticks([i for i in _section_num.keys()])
axs.set_xticklabels(_section_num.keys(), fontsize=13)

plt.show()

# %% [markdown]
# ## Augmentation

# %%
from copy import deepcopy
train_points = h5py.File('./data/train.h5', 'r')

# %%
def jittering(point, scale_range) :
    point += np.random.uniform(*scale_range, size=point.shape) 
    return point

def scaling(point, scale_range) :
    point *= np.random.uniform(*scale_range)
    return point

def rand_sampling(point) :
    point_num = point.shape[0]

    if point_num >= 20000 :
        sampling_rate=0.6
    else :
        sampling_rate=0.8

    sampling_idx = np.sort(np.random.choice(point_num, int(point_num * sampling_rate) , replace=False))
    point = point[sampling_idx, :]
    return point

# %% [markdown]
# ### training set point 범위

# %%
'''
약 2분30초 소요
'''
# xyzmin = []
# xyzmax = []
# for i in tqdm(range(50000)) :
#     xyzmin.append(np.min(all_points[str(i)], axis=0))
#     xyzmax.append(np.max(all_points[str(i)], axis=0))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [02:12<00:00, 378.07it/s]

# %%
# _xyzmin = np.min(np.array(xyzmin), axis=0)
# _xyzmax = np.max(np.array(xyzmax), axis=0)
# print("xyzmin : ", _xyzmin)
# print("xyzmax : ", _xyzmax)
# print("x range : ",_xyzmin[0]," ~ ",_xyzmax[0])
# print("y range : ",_xyzmin[1]," ~ ",_xyzmax[1])
# print("z range : ",_xyzmin[2]," ~ ",_xyzmax[2])
# Out:
# xyzmin :  [-0.15789474 -0.70229885 -0.67952055]
# xyzmax :  [0.15789474 0.68434685 0.6597181 ]
# x range :  -0.15789473684212604  ~  0.15789473684210517
# y range :  -0.7022988505747477  ~  0.6843468468468135
# z range :  -0.6795205479452088  ~  0.6597181008902087

# %%
# # point cloud range
# xrange = (round(_xyzmin[0], 4), round(_xyzmax[0], 4))
# yrange = (round(_xyzmin[1], 4), round(_xyzmax[1], 4))
# zrange = (round(_xyzmin[2], 4), round(_xyzmax[2], 4))
# vd = 0.4
# vh = 0.2
# vw = 0.2

# %%
# print("x range : ",xrange)
# print("y range : ",yrange)
# print("z range : ",zrange)
# Out:
# x range :  (-0.1579, 0.1579)
# y range :  (-0.7023, 0.6843)
# z range :  (-0.6795, 0.6597)

# %%
x_range = (-0.1579, 0.1579)
y_range = (-0.7023, 0.6843)
z_range = (-0.6795, 0.6597)

x_range_value, x_range_term = np.linspace(*x_range , num=1000, retstep=True)
y_range_value, y_range_term = np.linspace(*y_range , num=1000, retstep=True)
z_range_value, z_range_term = np.linspace(*z_range , num=1000, retstep=True)

x_range_dist = np.array([0] * 1001)
y_range_dist = np.array([0] * 1001)
z_range_dist = np.array([0] * 1001)

for i in tqdm(range(50000)) :
    points = np.array(all_points[str(i)])

    x_uniq, x_count = np.unique(np.searchsorted(x_range_value, points[:, 0]), return_counts=True)
    y_uniq, y_count = np.unique(np.searchsorted(y_range_value, points[:, 1]), return_counts=True)
    z_uniq, z_count = np.unique(np.searchsorted(z_range_value, points[:, 2]), return_counts=True)
    
    x_range_dist[x_uniq] += x_count
    y_range_dist[y_uniq] += y_count
    z_range_dist[z_uniq] += z_count
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [02:17<00:00, 364.84it/s]

# %%
x_range_value_pick = x_range_value[np.where(x_range_dist[:] != 0)[0]]
y_range_value_pick = y_range_value[np.where(y_range_dist[:-1] != 0)[0]]
z_range_value_pick = z_range_value[np.where(z_range_dist[:-1] != 0)[0]]

fig, axes = plt.subplots(3,1, figsize=(15, 15))
axs = axes.flatten()
axs[0].plot(x_range_value_pick, x_range_dist[x_range_dist[:]!=0])
axs[0].set_title('X - axis', fontsize=20)
axs[1].plot(y_range_value_pick, y_range_dist[y_range_dist[:]!=0][:-1])
axs[1].set_title('Y - axis', fontsize=20)
axs[2].plot(z_range_value_pick, z_range_dist[z_range_dist[:]!=0][:-1])
axs[2].set_title('Z - axis', fontsize=20)
plt.show()

# %%
highest = np.where(x_range_dist[x_range_dist[:]!=0] > 12000000)[0]
print(x_range_dist[x_range_dist[:]!=0].shape)
print("X축에서 가장 많은 데이터가 누적된 값\n",x_range_value_pick[highest])
print("가장 큰 누적값\n",x_range_dist[x_range_dist[:]!=0][highest])
# Out:
# (60,)
# X축에서 가장 많은 데이터가 누적된 값
#  [-0.1499971  -0.13956527 -0.12913343 -0.1187016  -0.10858589 -0.09815405
#  -0.08772222 -0.07729039 -0.06717467 -0.05674284 -0.04631101 -0.0361953
#  -0.02576346 -0.01533163 -0.0048998   0.00521592  0.01564775  0.02607958
#   0.03651141  0.04662713  0.05705896  0.06749079  0.07760651  0.08803834
#   0.09847017  0.108902    0.11901772  0.12944955  0.13988138  0.15031321]
# 가장 큰 누적값
#  [212693445  25139170  25139170  25139170  25139170  25139170  25139170
#   25139170  25139170  25139170  25139170  25139170  25139170  25139170
#   25139170  25139170  25139170  25139170  25139170  25139170  25139170
#   25139170  25139170  25139170  25139170  25139170  25139170  25139170
#   25139170 212693445]

# %% [markdown]
# - x축 그래프에서 위로 솟아 있는 부분은 모두 1200만개 이상의 점들이 누적되어 있음

# %% [markdown]
# ### Test set point 범위

# %%
test_points = h5py.File('./data/test.h5', 'r')
xyzmin = []
xyzmax = []
for i in tqdm(range(50000, 90000)) :
    xyzmin.append(np.min(test_points[str(i)], axis=0))
    xyzmax.append(np.max(test_points[str(i)], axis=0))
    
_xyzmin = np.min(np.array(xyzmin), axis=0)
_xyzmax = np.max(np.array(xyzmax), axis=0)
xrange = (round(_xyzmin[0], 4), round(_xyzmax[0], 4))
yrange = (round(_xyzmin[1], 4), round(_xyzmax[1], 4))
zrange = (round(_xyzmin[2], 4), round(_xyzmax[2], 4))

print("x range : ",xrange)
print("y range : ",yrange)
print("z range : ",zrange)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [02:43<00:00, 245.05it/s]
# x range :  (-0.7839, 0.7732)
# y range :  (-0.7591, 0.7707)
# z range :  (-0.7849, 0.7697)

# %%
test_points = h5py.File('./data/test.h5', 'r')

tx_range = (-0.7839, 0.7732)
ty_range = (-0.7591, 0.7707)
tz_range = (-0.7849, 0.7697)

tx_range_value, tx_range_term = np.linspace(*tx_range , num=1000, retstep=True)
ty_range_value, ty_range_term = np.linspace(*ty_range , num=1000, retstep=True)
tz_range_value, tz_range_term = np.linspace(*tz_range , num=1000, retstep=True)

tx_range_dist = np.array([0] * 1001)
ty_range_dist = np.array([0] * 1001)
tz_range_dist = np.array([0] * 1001)

for i in tqdm(range(50000, 90000)) :
    points = np.array(test_points[str(i)])

    x_uniq, x_count = np.unique(np.searchsorted(tx_range_value, points[:, 0]), return_counts=True)
    y_uniq, y_count = np.unique(np.searchsorted(ty_range_value, points[:, 1]), return_counts=True)
    z_uniq, z_count = np.unique(np.searchsorted(tz_range_value, points[:, 2]), return_counts=True)
    
    tx_range_dist[x_uniq] += x_count
    ty_range_dist[y_uniq] += y_count
    tz_range_dist[z_uniq] += z_count
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [02:41<00:00, 247.43it/s]

# %%
tx_range_value_pick = tx_range_value[np.where(tx_range_dist[:-1] != 0)[0]]
ty_range_value_pick = ty_range_value[np.where(ty_range_dist[:-1] != 0)[0]]
tz_range_value_pick = tz_range_value[np.where(tz_range_dist[:-1] != 0)[0]]

fig, axes = plt.subplots(3,1, figsize=(15, 15))
axs = axes.flatten()
axs[0].plot(tx_range_value_pick, tx_range_dist[tx_range_dist[:]!=0][:-1])
axs[0].set_title('X - axis', fontsize=20)
axs[1].plot(ty_range_value_pick, ty_range_dist[ty_range_dist[:]!=0])
axs[1].set_title('Y - axis', fontsize=20)
axs[2].plot(tz_range_value_pick, tz_range_dist[tz_range_dist[:]!=0])
axs[2].set_title('Z - axis', fontsize=20)
plt.show()

# %%
highest = np.where(tx_range_dist[tx_range_dist[:]!=0][:-1] > 12000000)[0]
print("X축에서 가장 많은 데이터가 누적된 값\n",tx_range_value_pick[highest])
print("가장 큰 누적값\n",tx_range_dist[tx_range_dist[:]!=0][:-1][highest])
# Out:
# X축에서 가장 많은 데이터가 누적된 값
#  [-0.14952593  0.1512952 ]
# 가장 큰 누적값
#  [86049208 86048486]

# %% [markdown]
# ## test set x축 범위 cliping

# %%
test_points = h5py.File('./data/test.h5', 'r')

tx_range = (-0.7839, 0.7732)
ty_range = (-0.7591, 0.7707)
tz_range = (-0.7849, 0.7697)

tx_range_value, tx_range_term = np.linspace(*tx_range , num=1000, retstep=True)
ty_range_value, ty_range_term = np.linspace(*ty_range , num=1000, retstep=True)
tz_range_value, tz_range_term = np.linspace(*tz_range , num=1000, retstep=True)

tx_range_dist = np.array([0] * 1001)
ty_range_dist = np.array([0] * 1001)
tz_range_dist = np.array([0] * 1001)

for i in tqdm(range(50000, 90000)) :
    points = np.array(test_points[str(i)])

    x_uniq, x_count = np.unique(np.searchsorted(tx_range_value, np.clip(points[:, 0], -0.15, 0.15)), return_counts=True)
    y_uniq, y_count = np.unique(np.searchsorted(ty_range_value, points[:, 1]), return_counts=True)
    z_uniq, z_count = np.unique(np.searchsorted(tz_range_value, points[:, 2]), return_counts=True)
    
    tx_range_dist[x_uniq] += x_count
    ty_range_dist[y_uniq] += y_count
    tz_range_dist[z_uniq] += z_count
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 40000/40000 [02:36<00:00, 256.28it/s]

# %%
tx_range_value_pick = tx_range_value[np.where(tx_range_dist != 0)[0]]
ty_range_value_pick = ty_range_value[np.where(ty_range_dist[:-1] != 0)[0]]
tz_range_value_pick = tz_range_value[np.where(tz_range_dist[:-1] != 0)[0]]

fig, axes = plt.subplots(3,1, figsize=(15, 15))
axs = axes.flatten()
axs[0].plot(tx_range_value_pick, tx_range_dist[tx_range_dist[:]!=0])
axs[0].set_title('X - axis', fontsize=20)
axs[1].plot(ty_range_value_pick, ty_range_dist[ty_range_dist[:]!=0])
axs[1].set_title('Y - axis', fontsize=20)
axs[2].plot(tz_range_value_pick, tz_range_dist[tz_range_dist[:]!=0])
axs[2].set_title('Z - axis', fontsize=20)
plt.show()

# %%
highest = np.where(tx_range_dist[tx_range_dist[:]!=0] > 10000000)[0]
print("X축에서 가장 많은 데이터가 누적된 값\n",tx_range_value_pick[highest])
print("가장 큰 누적값\n",tx_range_dist[tx_range_dist[:]!=0][highest])
# Out:
# X축에서 가장 많은 데이터가 누적된 값
#  [-0.14952593 -0.13861532 -0.12926336 -0.11835275 -0.10744214 -0.09809019
#  -0.08717958 -0.07626897 -0.06691702 -0.05600641 -0.0450958  -0.03574384
#  -0.02483323 -0.01548128 -0.00457067  0.00633994  0.01569189  0.0266025
#   0.03751311  0.04686507  0.05777568  0.06868629  0.07803824  0.08894885
#   0.0983008   0.10921141  0.12012202  0.12947397  0.14038458  0.1512952 ]
# 가장 큰 누적값
#  [216664602  11026701  11033987  11048941  11055851  11065427  11070550
#   11075229  11085106  11090451  11091013  11092949  11099299  11107173
#   11108365  11105855  11100449  11099536  11093938  11096358  11090932
#   11085146  11077501  11073858  11064692  11057489  11041966  11034441
#   11025616 216409629]

# %%
'''
https://jehyunlee.github.io/2021/07/10/Python-DS-80-mpl3d2/
'''
from matplotlib import animation 
f, axs = plt.subplots(1,2, figsize=(15, 5), subplot_kw={"projection":'3d'})

data1 = {"x" : all_points["55"][:,0],
        "y" : all_points["55"][:,1],
        "z" : all_points["55"][:,2]}

data2 = {"x" : all_points["555"][:,0],
        "y" : all_points["555"][:,1],
        "z" : all_points["555"][:,2]}

def init():
    for ax, data in zip(axs, [data1, data2]):
        ax.set_xlabel("X")
        ax.set_ylabel("Y")
    
        ax.scatter(data["x"], data["y"], data["z"], cmap="inferno", s=3, alpha=0.1)
    
    return f,

def animate(i):
    axs[0].view_init(elev=30., azim=i)
    axs[1].view_init(elev=30., azim=i)
    return fig,

# Animate
# anim = animation.FuncAnimation(f, animate, init_func=init, frames=360, interval=20, blit=True)
# Save
# anim.save('mpl3d_scatter.gif', fps=30)

# %% [markdown]
# ![SegmentLocal](mpl3d_scatter.gif "segment")

# %%
test_points = h5py.File('./data/test.h5', 'r')
f, axs = plt.subplots(3,4, figsize=(15, 15), subplot_kw={"projection":'3d'})

axs = axs.flatten()
rand_pick = np.random.randint(50000,90000,size=12)

for i, pick in enumerate(rand_pick) :
    x = test_points[str(pick)][:,0]
    y = test_points[str(pick)][:,1]
    z = test_points[str(pick)][:,2]

    axs[i].scatter(x,y,z, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
    axs[i].set_title(str(test_points[str(pick)][:].shape))
    axs[i].view_init(elev=90. ,azim=-5)

# %% [markdown]
# - test 셋의 경우 회전되어 있는 데이터도 존재
# - 6이나 9 같은 경우 상,하로도 뒤집혀 있는지 확인해야할 듯
#     - 6과 9가 상하로 뒤집혀 있으면 라벨이 바뀌게됨

# %% [markdown]
# ## Clipping Point Visualization

# %%
test_points = h5py.File('./data/test.h5', 'r')
f, axs = plt.subplots(3,4, figsize=(15, 15), subplot_kw={"projection":'3d'})

axs = axs.flatten()
rand_pick = np.random.randint(50000,90000,size=12)

train_range = np.array([(-0.1579, 0.1579), (-0.7023, 0.6843), (-0.6795, 0.6597)])
test_range = np.array([(-0.7839, 0.7732), (-0.7591, 0.7707), (-0.7849, 0.7697)])
axis = [1,2]
for i, pick in enumerate(rand_pick) :

    point = np.array(test_points[str(pick)])
    point[:, 0] = np.clip(point[:, 0], -0.15, 0.15)
    point[:, axis] = point[:, axis] /  np.max(np.abs(test_range[axis])) * np.max(np.abs(train_range[axis]))
                                                                                            
    x = point[:,0]
    y = point[:,1]
    z = point[:,2]

    axs[i].scatter(x,y,z, marker='^', cmap="inferno",s=3, alpha=0.1)
    axs[i].set_xlabel("X")
    axs[i].set_ylabel("Y")
    axs[i].set_title(str(test_points[str(pick)][:].shape))
    axs[i].view_init(elev=30.)

# %%
test_points = h5py.File('./data/test.h5', 'r')
total_size = []
for i in tqdm(range(50000, 90000)) :
    total_size.append(test_points[str(i)].shape[0])
    

section_list = {k : [] for k in range(8000,38000, 2000)}
section_num = {str(k) : 0 for k in range(8000,38000, 2000)}

for i, shape in enumerate(total_size) :
    for k in section_list.keys() :
        if k < shape and shape <= k + 2000 :
            section_list[k].append((shape, str(50000+i))) 
            section_num[str(k)] += 1
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 40000/40000 [00:02<00:00, 14151.23it/s]

# %%
f, axs = plt.subplots(1,1, figsize=(15, 7))

axs.bar(section_num.keys(), section_num.values(), color=['#e6e6fa' if a%2==0 else '#50bcdf' for a in range(len(section_num))])
for k, v in section_num.items() :
    axs.annotate('%d'%(v), xy=(k, v), ha='center',fontsize=15)

axs.set_xticks([i for i in section_num.keys()])
axs.set_xticklabels(section_num.keys(), fontsize=13)

plt.show()
